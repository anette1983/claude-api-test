# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]
    strengths = model_grade["strengths"]
    weaknesses = model_grade["weaknesses"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
        "strengths": strengths,
        "weaknesses": weaknesses,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.166666666666666

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport json\nimport sys\n\ndef extract_lambda_functions(template_str):\n    template = json.loads(template_str)\n    lambda_ids = []\n    \n    if 'Resources' in template:\n        for logical_id, resource in template['Resources'].items():\n            if resource.get('Type') == 'AWS::Lambda::Function':\n                lambda_ids.append(logical_id)\n    \n    return lambda_ids\n\nif __name__ == '__main__':\n    template_input = sys.stdin.read()\n    result = extract_lambda_functions(template_input)\n    print(json.dumps(result, indent=2))\n",
#     "test_case": {
#       "task": "Parse an AWS CloudFormation template and extract all resource logical IDs that are of type 'AWS::Lambda::Function'",
#       "format": "python",
#       "solution_criteria": "The solution should return a list of logical IDs for all Lambda functions defined in the template. Should handle both JSON and YAML CloudFormation formats."
#     },
#     "score": 7.5,
#     "reasoning": "The solution correctly implements the core functionality for JSON templates but fails to meet the stated requirement of handling both JSON and YAML formats. YAML is a commonly used CloudFormation format, and the absence of YAML support is a critical gap. Additionally, the solution lacks robust error handling for invalid input. To fully meet the criteria, it should use a YAML parser (like PyYAML) to handle both formats, and include try-catch blocks with informative error messages.",
#     "strengths": [
#       "Correctly parses JSON CloudFormation templates and accurately extracts Lambda function logical IDs",
#       "Includes proper error handling for missing 'Resources' section and safely accesses nested dictionary values using .get()",
#       "Clean, readable code with appropriate use of dictionary iteration and filtering logic"
#     ],
#     "weaknesses": [
#       "Does not support YAML CloudFormation format, which is explicitly required by the criteria",
#       "No error handling for malformed JSON input - will crash with unhelpful error messages",
#       "Missing validation that extracted logical IDs are actually valid identifiers"
#     ]
#   },
#   {
#     "output": "\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    },\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    }\n  ]\n}\n",
#     "test_case": {
#       "task": "Create a JSON IAM policy document that allows a principal to perform read-only operations (GetObject, ListBucket) on a specific S3 bucket named 'my-data-bucket'",
#       "format": "json",
#       "solution_criteria": "The JSON must be valid IAM policy syntax with correct Effect, Action, Resource, and Principal fields. Should grant only read permissions."
#     },
#     "score": 9.0,
#     "reasoning": "The policy correctly implements the core requirements with valid syntax and proper permission scoping. The separation of bucket-level (ListBucket on bucket ARN) and object-level (GetObject on objects ARN) permissions demonstrates good understanding of S3 ARN structure. However, the absence of a Principal field limits its completeness as a standalone policy document, though this may be intentional if it's meant as an inline policy template. The read-only restriction is properly maintained.",
#     "strengths": [
#       "Valid JSON syntax with correct IAM policy structure following AWS 2012-10-17 version",
#       "Properly separates permissions into two statements with correct Resource ARNs for bucket and objects",
#       "Grants only read-only permissions (GetObject and ListBucket) as required, with no write/delete actions"
#     ],
#     "weaknesses": [
#       "Missing Principal field - while optional in some contexts (like inline policies), it should be included for standalone policy documents to be complete",
#       "Does not include s3:GetObjectVersion or other potential read operations that might be needed in real-world scenarios"
#     ]
#   },
#   {
#     "output": "\narn:aws:[a-z0-9\\-]*:[a-z0-9\\-]*:[0-9]{12}:[a-zA-Z0-9\\-/_\\.]*\n",
#     "test_case": {
#       "task": "Write a regex pattern to match and validate AWS ARNs (Amazon Resource Names) in their standard format",
#       "format": "regex",
#       "solution_criteria": "The regex should match valid ARN formats like 'arn:aws:service:region:account-id:resource' and reject invalid formats. Should be flexible enough to handle various AWS services."
#     },
#     "score": 8.0,
#     "reasoning": "The regex captures the core ARN structure and would work for many standard cases like EC2 instances and S3 buckets. However, it lacks anchors for strict matching, doesn't handle AWS partition variations, and is too lenient on the resource component. For production use, it needs refinement to reject edge cases and support all ARN formats.",
#     "strengths": [
#       "Correctly matches the basic ARN structure with literal 'arn:aws:' prefix",
#       "Handles 12-digit account IDs accurately with [0-9]{12}",
#       "Includes character classes for service, region, and resource components with reasonable flexibility"
#     ],
#     "weaknesses": [
#       "Missing anchor markers (^ and $) allows partial matches; 'arn:aws:s3:::bucket' embedded in larger strings would incorrectly match",
#       "Does not account for ARN variations like partition (e.g., 'arn:aws-cn:' or 'arn:aws-us-gov:') or resource-only ARNs that omit region/account",
#       "Resource component pattern [a-zA-Z0-9\\-/_\\.]* is overly permissive and may match invalid resource formats; some AWS services have stricter naming requirements"
#     ]
#   }
# ]
