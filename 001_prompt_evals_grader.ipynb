# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]
    strengths = model_grade["strengths"]
    weaknesses = model_grade["weaknesses"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
        "strengths": strengths,
        "weaknesses": weaknesses,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 5.333333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# Extract AWS Region from S3 Bucket ARN\n\nHere's a solution to extract the AWS region from an S3 bucket ARN:\n\n```python\nimport re\n\ndef extract_region_from_s3_arn(arn):\n    \"\"\"\n    Extract AWS region from an S3 bucket ARN.\n    \n    Args:\n        arn (str): S3 bucket ARN (e.g., arn:aws:s3:::my-bucket-us-east-1)\n    \n    Returns:\n        str: AWS region or None if not found\n    \"\"\"\n    # S3 bucket ARN format: arn:aws:s3:::bucket-name\n    # Note: Standard S3 bucket ARNs don't contain region info\n    # Region info is typically in the bucket name itself\n    \n    # Extract bucket name from ARN\n    match = re.search(r'arn:aws:s3:::([a-z0-9\\-\\.]+)', arn)\n    if not match:\n        return None\n    \n    bucket_name = match.group(1)\n    \n    # Common AWS regions to search for\n    regions = [\n        'us-east-1', 'us-east-2', 'us-west-1', 'us-west-2',\n        'eu-west-1', 'eu-central-1', 'eu-north-1', 'eu-west-2', 'eu-west-3',\n        'ap-southeast-1', 'ap-southeast-2', 'ap-northeast-1', 'ap-northeast-2', 'ap-south-1',\n        'ca-central-1', 'sa-east-1'\n    ]\n    \n    # Search for region in bucket name\n    for region in regions:\n        if region in bucket_name:\n            return region\n    \n    return None\n\n# Test cases\ntest_arns = [\n    \"arn:aws:s3:::my-bucket-us-east-1\",\n    \"arn:aws:s3:::data-eu-west-1-prod\",\n    \"arn:aws:s3:::app-ap-northeast-1\",\n    \"arn:aws:s3:::generic-bucket\"\n]\n\nfor arn in test_arns:\n    region = extract_region_from_s3_arn(arn)\n    print(f\"ARN: {arn}\")\n    print(f\"Region: {region}\\n\")\n```\n\n**Output:**\n```\nARN: arn:aws:s3:::my-bucket-us-east-1\nRegion: us-east-1\n\nARN: arn:aws:s3:::data-eu-west-1-prod\nRegion: eu-west-1\n\nARN: arn:aws:s3:::app-ap-northeast-1\nRegion: ap-northeast-1\n\nARN: arn:aws:s3:::generic-bucket\nRegion: None\n```\n\n## Key Points:\n\n1. **S3 ARN Format**: `arn:aws:s3:::bucket-name` (no region field in standard ARN)\n2. **Region Extraction**: Region is typically embedded in the bucket name itself\n3. **Pattern Matching**: Searches for known AWS region identifiers within the bucket name\n4. **Flexible**: Handles regions anywhere in the bucket name\n\nThis solution handles the most common AWS regions, but you can easily add more regions to the list as needed.",
#     "test_case": {
#       "task": "Extract the AWS region from an S3 bucket ARN (e.g., arn:aws:s3:::my-bucket-us-east-1)",
#       "format": "regex"
#     },
#     "score": 5,
#     "reasoning": "The solution correctly addresses the core architectural insight that S3 bucket ARNs lack region fields. However, the implementation has significant quality issues. The substring matching approach is too simplistic and will produce false positives/negatives. For example, it would incorrectly match 'us-east-1a' or fail if a region name appears as part of another word. The lack of input validation and error handling also reduces robustness. A production-ready solution should use regex anchors/word boundaries to match region codes as distinct segments within the bucket name.",
#     "strengths": [
#       "Correctly identifies that standard S3 bucket ARNs don't contain region information and must infer it from the bucket name",
#       "Includes clear documentation, comments, and test cases demonstrating the function's behavior",
#       "Covers a comprehensive list of AWS regions for pattern matching"
#     ],
#     "weaknesses": [
#       "Critical flaw: The regex pattern and bucket name extraction don't validate proper ARN structure - accepts malformed ARNs without error handling",
#       "Fragile substring matching: searching for 'eu-west-1' in bucket name could produce false positives (e.g., 'my-eu-west-1a-bucket' or 'bucket-not-eu-west-1-region'). Should use regex with word boundaries to match region codes as distinct segments",
#       "Hardcoded region list becomes unmaintainable as AWS expands regions; should either fetch from AWS API or clearly document that manual updates are required"
#     ]
#   },
#   {
#     "output": "# CloudFormation Template for S3 Bucket with Versioning and Public Access Blocked\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for an S3 bucket with versioning enabled and public access blocked\",\n  \"Resources\": {\n    \"S3Bucket\": {\n      \"Type\": \"AWS::S3::Bucket\",\n      \"Properties\": {\n        \"BucketName\": \"my-secure-bucket-12345\",\n        \"VersioningConfiguration\": {\n          \"Status\": \"Enabled\"\n        }\n      }\n    },\n    \"S3BucketPublicAccessBlock\": {\n      \"Type\": \"AWS::S3::BucketPublicAccessBlock\",\n      \"Properties\": {\n        \"BucketName\": {\n          \"Ref\": \"S3Bucket\"\n        },\n        \"BlockPublicAcls\": true,\n        \"BlockPublicPolicy\": true,\n        \"IgnorePublicAcls\": true,\n        \"RestrictPublicBuckets\": true\n      }\n    }\n  },\n  \"Outputs\": {\n    \"BucketName\": {\n      \"Description\": \"Name of the S3 bucket\",\n      \"Value\": {\n        \"Ref\": \"S3Bucket\"\n      }\n    },\n    \"BucketArn\": {\n      \"Description\": \"ARN of the S3 bucket\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"S3Bucket\",\n          \"Arn\"\n        ]\n      }\n    }\n  }\n}\n```\n\n## Key Features:\n\n| Feature | Details |\n|---------|---------|\n| **Versioning** | Enabled via `VersioningConfiguration` with Status: \"Enabled\" |\n| **Public Access Block** | All four blocking options enabled: |\n| | \u2022 BlockPublicAcls: true |\n| | \u2022 BlockPublicPolicy: true |\n| | \u2022 IgnorePublicAcls: true |\n| | \u2022 RestrictPublicBuckets: true |\n| **Outputs** | Provides bucket name and ARN for reference |\n\n## Usage:\n\n1. **Replace bucket name**: Change `\"my-secure-bucket-12345\"` to your desired bucket name (must be globally unique)\n2. **Deploy**: Use AWS CLI or CloudFormation console\n   ```bash\n   aws cloudformation create-stack \\\n     --stack-name my-s3-stack \\\n     --template-body file://template.json\n   ```\n\nThis template creates a production-ready S3 bucket with security best practices enabled!",
#     "test_case": {
#       "task": "Create a CloudFormation template JSON object for an S3 bucket with versioning enabled and public access blocked",
#       "format": "json"
#     },
#     "score": 7,
#     "reasoning": "The solution successfully fulfills the core requirements with correct CloudFormation syntax and good security posture. However, it has a notable practical flaw: the hard-coded bucket name will fail on deployment unless changed, and this limitation isn't adequately addressed in the usage instructions. The missing explicit dependency is a minor issue that could cause problems in certain deployment scenarios. The documentation is clear and helpful, which is a positive aspect.",
#     "strengths": [
#       "Correctly implements all required features: versioning is enabled and all four public access block settings are properly configured",
#       "Well-structured template with proper CloudFormation syntax, includes helpful outputs for bucket name and ARN, and provides clear usage instructions",
#       "Follows AWS security best practices by comprehensively blocking public access through all available mechanisms"
#     ],
#     "weaknesses": [
#       "Hard-coded bucket name 'my-secure-bucket-12345' violates best practices since S3 bucket names must be globally unique; should use Parameters or logical naming instead",
#       "Missing explicit dependency between S3Bucket and S3BucketPublicAccessBlock resources, which could cause timing issues in some scenarios (should add DependsOn property)"
#     ]
#   },
#   {
#     "output": "# AWS IAM Role ARN Validator\n\nHere's a comprehensive solution to validate AWS IAM role ARNs:\n\n```python\nimport re\nfrom typing import Union\n\ndef is_valid_iam_role_arn(arn: str) -> bool:\n    \"\"\"\n    Validates if a given string is a valid AWS IAM role ARN.\n    \n    AWS IAM Role ARN format:\n    arn:aws:iam::account-id:role/role-name\n    \n    Where:\n    - Partition: 'aws' (or 'aws-cn', 'aws-us-gov' for other regions)\n    - Account ID: 12-digit number\n    - Role name: 1-64 characters, alphanumeric and special chars (+=,.@_-)\n    \n    Args:\n        arn: String to validate\n        \n    Returns:\n        bool: True if valid IAM role ARN, False otherwise\n        \n    Examples:\n        >>> is_valid_iam_role_arn(\"arn:aws:iam::123456789012:role/MyRole\")\n        True\n        >>> is_valid_iam_role_arn(\"arn:aws:iam::123456789012:role/my-role-123\")\n        True\n        >>> is_valid_iam_role_arn(\"arn:aws:iam::123456789012:user/MyUser\")\n        False\n        >>> is_valid_iam_role_arn(\"invalid-arn\")\n        False\n    \"\"\"\n    \n    if not isinstance(arn, str) or not arn.strip():\n        return False\n    \n    # AWS IAM Role ARN pattern\n    # arn:partition:iam::account-id:role/role-name\n    pattern = r'^arn:(aws|aws-cn|aws-us-gov):iam::\\d{12}:role/[a-zA-Z0-9\\-+=,.@_]{1,64}$'\n    \n    return bool(re.match(pattern, arn))\n\n\ndef validate_iam_role_arn_detailed(arn: str) -> dict:\n    \"\"\"\n    Validates IAM role ARN and provides detailed information about validation.\n    \n    Args:\n        arn: String to validate\n        \n    Returns:\n        dict: Validation result with details\n        \n    Examples:\n        >>> validate_iam_role_arn_detailed(\"arn:aws:iam::123456789012:role/MyRole\")\n        {\n            'valid': True,\n            'arn': 'arn:aws:iam::123456789012:role/MyRole',\n            'partition': 'aws',\n            'account_id': '123456789012',\n            'role_name': 'MyRole',\n            'errors': []\n        }\n    \"\"\"\n    \n    errors = []\n    result = {\n        'valid': False,\n        'arn': arn,\n        'partition': None,\n        'account_id': None,\n        'role_name': None,\n        'errors': []\n    }\n    \n    # Check if input is string\n    if not isinstance(arn, str):\n        errors.append(\"Input must be a string\")\n        result['errors'] = errors\n        return result\n    \n    if not arn.strip():\n        errors.append(\"ARN cannot be empty\")\n        result['errors'] = errors\n        return result\n    \n    # Parse ARN structure\n    parts = arn.split(':')\n    \n    if len(parts) != 6:\n        errors.append(f\"ARN must have 6 parts separated by ':', got {len(parts)}\")\n        result['errors'] = errors\n        return result\n    \n    # Validate each part\n    if parts[0] != 'arn':\n        errors.append(f\"ARN must start with 'arn', got '{parts[0]}'\")\n    \n    if parts[1] not in ['aws', 'aws-cn', 'aws-us-gov']:\n        errors.append(f\"Invalid partition '{parts[1]}', must be 'aws', 'aws-cn', or 'aws-",
#     "test_case": {
#       "task": "Write a Python function that validates if a given string is a valid AWS IAM role ARN",
#       "format": "python"
#     },
#     "score": 4,
#     "reasoning": "The solution demonstrates good design principles and documentation, but is severely hampered by an incomplete implementation that cuts off mid-function. The regex pattern has a logical flaw with character ordering that allows invalid names. The detailed validator function, which would have added significant value, is truncated and non-functional. While the basic `is_valid_iam_role_arn()` function works for standard cases, these issues prevent this from being a reliable production solution.",
#     "strengths": [
#       "Provides both simple validation function and detailed parsing function with good separation of concerns",
#       "Comprehensive documentation with clear ARN format explanation and multiple examples",
#       "Proper input validation (type checking, empty string handling) with defensive programming practices"
#     ],
#     "weaknesses": [
#       "Solution is incomplete - the `validate_iam_role_arn_detailed()` function is cut off mid-implementation, making it non-functional",
#       "Regex pattern allows role names starting with hyphens (e.g., 'role/-invalid') which AWS doesn't permit; should use `[a-zA-Z0-9]` at start",
#       "Missing edge case handling: doesn't validate role name length constraints properly or handle path prefixes in role names (e.g., 'role/path/to/role')"
#     ]
#   }
# ]
